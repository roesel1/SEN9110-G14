# %%
import salabim as sim

env = sim.Environment(time_unit='seconds')



#Shopping baskets and carts:
carts = env.Resource('carts', capacity=45) #45
baskets = env.Resource('baskets', capacity=500)#several hundred
cart_basket_distribution = sim.Pdf((carts, 0.8,baskets, 0.2))
customer_basketcart_distribution_monitor = sim.Monitor("Customer basket and cart monitor")
#shopping categories:
# fruit_and_vegetables 
# meat_and_fish
# bread
# cheese_and_dairy
# canned_and_packed_food
# frozen_foods
# drinks
item_taking_distribution = sim.Uniform(20,30)

#Clerks
#Bread and cheese use resources as they are working via counters. Checkout likely has to use queue as the customers need to choose the smallest one
bread_clerks = env.Resource('bread_clerks', capacity=4) #4 employees, 1-6 items takes 2 min
bread_time_distribution = sim.Exponential(2*60)
cheese_and_dairy_clerks = env.Resource('bread_clerks', capacity=3) #3 employees, 1 min avg.
cheese_and_dairy_time_distribution = sim.Exponential(1*60)

#Checkouts
number_of_checkouts = 3
time_per_item_distribution = sim.Exponential(1.1)
payment_time_distribution = sim.Uniform(40, 60)

#Distributions of items per customer
fruit_and_vegetables_distribution = sim.Triangular(4, 22,10)  # min=4, mode=10, max=22
meat_and_fish_distribution = sim.Triangular(0, 9, 4)           # min=0, mode=4, max=9
bread_distribution = sim.Triangular(1, 10, 4)                  # min=1, mode=4, max=10
cheese_and_dairy_distribution = sim.Triangular(1, 11, 3)       # min=1, mode=3, max=11
canned_and_packed_food_distribution = sim.Triangular(6, 35, 17)# min=6, mode=17, max=35
frozen_foods_distribution = sim.Triangular(2, 19, 8)           # min=2, mode=8, max=19
drinks_distribution = sim.Triangular(1, 20, 9)                 # min=1, mode=9, max=20

#Route choice distribution

#Routes
route1 = [
"fruit_and_vegetables",
"meat_and_fish",
"bread",
"cheese_and_dairy",
"canned_and_packed_food",
"frozen_foods",
"drinks",
] #ABCDEF, 80% 

route2 = [
"meat_and_fish",
"bread",
"cheese_and_dairy",
"fruit_and_vegetables",
"canned_and_packed_food",
"frozen_foods",
"drinks",
] #BCDEFG, 20%

route_distribution = sim.Pdf((route1, 0.8, route2, 0.2))
class Clerk(sim.Component):
    def __init__(self, checkout, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.checkout = checkout
        
    def process(self):
        while True:
            while len(self.checkout) == 0:
                self.passivate()
            self.customer = self.checkout.pop()
            self.customer.activate()  # get the customer out of it's hold()
            self.hold(sum(time_per_item_distribution.sample() for _ in sum(self.customer.shopping_list.values()))+payment_time_distribution.sample()) #hold the customer for scanning all items and during payment
            self.customer.activate()  # signal the customer that's all's done

class Customer(sim.Component):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.route = route_distribution.sample()
        self.shopping_list = {
            "fruit_and_vegetables": int(round(fruit_and_vegetables_distribution.sample())),
            "meat_and_fish": int(round(meat_and_fish_distribution.sample())),
            "bread": int(round(bread_distribution.sample())),
            "cheese_and_dairy": int(round(cheese_and_dairy_distribution.sample())),
            "canned_and_packed_food": int(round(canned_and_packed_food_distribution.sample())),
            "frozen_foods": int(round(frozen_foods_distribution.sample())),
            "drinks": int(round(drinks_distribution.sample())),
        }
        self.progress = 0
        self.carrying = None

    def process(self):
        """"
        Process determines what the customer will do. At the start they will take a cart or basket. Afterwards they will traverse their route and take the items they need according to their shopping list. If they have finished their route (when progress is equal to the length of the shopping list), they will go to the checkout.
        """
        if self.carrying is None:
            self.start_shopping()
        elif self.progress == len(self.shopping_list):
            self.go_to_checkout()
        else:
            next_product = self.route[self.progress]
            if self.shopping_list[next_product]>0:
                self.get_product(next_product)
            else: 
                self.progress += 1
                self.process()
            
    def start_shopping(self):
        #Get shopping cart or basket
        want_to_carry = cart_basket_distribution.sample()
        self.request(want_to_carry)
        customer_basketcart_distribution_monitor.tally(want_to_carry)
        self.carrying = want_to_carry
        self.process()
        
    def go_to_checkout(self):
        #enter emptiest queue
        emptiest_queue = min(checkouts, key=len)  
        self.enter(emptiest_queue) 
        #let clerk take items and wait
        clerk = checkouts[emptiest_queue]
        clerk.activate()
        self.hold()
        #return cart/basket
        self.carrying.release() #Technically not necessary as process terminates here
        
        
    def get_product(self, product):
        #Move to product location #<- only needed in animation
        if product == "cheese_and_dairy":
            self.request(cheese_and_dairy_clerks)
            self.hold(cheese_and_dairy_distribution.sample())
        elif product == "bread":
            self.request(bread_clerks)
            self.hold(bread_time_distribution.sample())
        else:
            amount = self.shopping_list[product]
            for _ in range(amount):
                self.hold(time_per_item_distribution.sample())
        self.progress += 1
        self.process()

#customer generation
customer_distribution = [30, 80, 110, 90, 80, 70, 80, 90, 100, 120, 90, 40] #Expected total = 980
for index, customer_count  in enumerate(customer_distribution):
    env.ComponentGenerator(Customer, iat=env.Exponential(3600/customer_count), at=index*60*60, duration=60*60) #assumes time in seconds
customer_arrival_monitor = sim.Monitor("Customer arrival monitor")

checkouts = {} #dictionary to map checkouts to clerks
for i in range(number_of_checkouts):
    checkouts[env.Queue(f"checkout{i}")] = Clerk(checkout=env.Queue(f"checkout{i}")) #3, 1.1s per item avg. payment 40-60s
# for j in checkouts:
#     Clerk(checkout = j)

env.run(duration=60*60*12)

for checkout in checkouts:
    checkout.length.print_histograms()
    
carts.print_statistics()
carts.print_info()
bread_clerks.print_statistics()
bread_clerks.print_info()
cheese_and_dairy_clerks.print_statistics()
cheese_and_dairy_clerks.print_info()

customer_basketcart_distribution_monitor.print_histogram(values=True)
# Out:
# Histogram of Length of checkout0
#                         all    excl.zero         zero
# -------------- ------------ ------------ ------------
# duration          43200        42655.583      544.417
# mean                142.576      144.396
# std.deviation        91.683       90.831
#
# minimum               0            1
# median              143          145
# 90% percentile      270          270
# 95% percentile      286          286
# maximum             300          300
#
#            <=      duration     %  cum%
#         0           544.417   1.3   1.3 *|
#        10          3303.881   7.6   8.9 ****** |
#        20          1306.807   3.0  11.9 **       |
#        30          1728.157   4.0  15.9 ***         |
#        40          1158.768   2.7  18.6 **            |
#        50          1408.680   3.3  21.9 **               |
#        60          1691.882   3.9  25.8 ***                 |
#        70          1203.572   2.8  28.6 **                    |
#        80          1202.526   2.8  31.4 **                       |
#        90          1334.617   3.1  34.5 **                         |
#       100          1120.133   2.6  37.0 **                           |
#       110          1261.718   2.9  40.0 **                             |
#       120          1263.543   2.9  42.9 **                                |
#       130          1349.231   3.1  46.0 **                                  |
#       140          1256.674   2.9  48.9 **                                     |
#       150          1427.360   3.3  52.2 **                                       |
#       160          1300.013   3.0  55.2 **                                          |
#       170          1540.790   3.6  58.8 **                                             |
#       180          1364.294   3.2  62.0 **                                               |
#       190          1063.394   2.5  64.4 *                                                  |
#       200          1348.501   3.1  67.5 **                                                    |
#       210          1337.230   3.1  70.6 **                                                      |
#       220          1720.575   4.0  74.6 ***                                                        |
#       230          1331.844   3.1  77.7 **                                                            |
#       240          1371.500   3.2  80.9 **                                                              |
#       250          1244.898   2.9  83.8 **                                                                 |
#       260          1406.166   3.3  87.0 **                                                                   |
#       270          1345.011   3.1  90.1 **                                                                      |
#       280          1364.152   3.2  93.3 **                                                                        |
#       290          1426.708   3.3  96.6 **                                                                           |
#       300          1472.959   3.4 100   **                                                                              |
#           inf         0       0   100                                                                                   |
#
# Histogram of Length of checkout1
#                         all    excl.zero         zero
# -------------- ------------ ------------ ------------
# duration          43200        42425.415      774.585
# mean                142.240      144.837
# std.deviation        91.688       90.466
#
# minimum               0            1
# median              142          146
# 90% percentile      269          270
# 95% percentile      285          286
# maximum             300          300
#
#            <=      duration     %  cum%
#         0           774.585   1.8   1.8 *|
#        10          3105.670   7.2   9.0 *****  |
#        20          1321.889   3.1  12.0 **       |
#        30          1728.457   4.0  16.0 ***         |
#        40          1174.497   2.7  18.8 **             |
#        50          1385.206   3.2  22.0 **               |
#        60          1681.718   3.9  25.9 ***                 |
#        70          1184.015   2.7  28.6 **                    |
#        80          1230.724   2.8  31.5 **                       |
#        90          1349.392   3.1  34.6 **                         |
#       100          1143.265   2.6  37.2 **                           |
#       110          1199.429   2.8  40.0 **                             |
#       120          1300.337   3.0  43.0 **                                |
#       130          1349.874   3.1  46.1 **                                  |
#       140          1228.200   2.8  49.0 **                                     |
#       150          1428.191   3.3  52.3 **                                       |
#       160          1318.854   3.1  55.3 **                                          |
#       170          1568.871   3.6  59.0 **                                             |
#       180          1312.231   3.0  62.0 **                                               |
#       190          1046.847   2.4  64.4 *                                                  |
#       200          1390.635   3.2  67.6 **                                                    |
#       210          1378.043   3.2  70.8 **                                                      |
#       220          1686.281   3.9  74.7 ***                                                        |
#       230          1304.831   3.0  77.8 **                                                            |
#       240          1478.457   3.4  81.2 **                                                              |
#       250          1187.947   2.7  83.9 **                                                                 |
#       260          1371.271   3.2  87.1 **                                                                   |
#       270          1350.071   3.1  90.2 **                                                                      |
#       280          1359.104   3.1  93.4 **                                                                        |
#       290          1434.419   3.3  96.7 **                                                                           |
#       300          1426.688   3.3 100.0 **                                                                             |
#           inf         0       0   100.0                                                                                |
#
# Histogram of Length of checkout2
#                         all    excl.zero         zero
# -------------- ------------ ------------ ------------
# duration          43200        42361.518      838.482
# mean                141.913      144.722
# std.deviation        91.655       90.335
#
# minimum               0            1
# median              142          146
# 90% percentile      269          270
# 95% percentile      285          285
# maximum             300          300
#
#            <=      duration     %  cum%
#         0           838.482   1.9   1.9 *|
#        10          3073.387   7.1   9.1 *****  |
#        20          1303.712   3.0  12.1 **       |
#        30          1743.227   4.0  16.1 ***         |
#        40          1168.093   2.7  18.8 **             |
#        50          1432.862   3.3  22.1 **               |
#        60          1634.543   3.8  25.9 ***                 |
#        70          1236.962   2.9  28.8 **                     |
#        80          1224.251   2.8  31.6 **                       |
#        90          1294.545   3.0  34.6 **                         |
#       100          1164.009   2.7  37.3 **                           |
#       110          1217.147   2.8  40.1 **                              |
#       120          1345.703   3.1  43.2 **                                |
#       130          1330.841   3.1  46.3 **                                   |
#       140          1223.623   2.8  49.1 **                                     |
#       150          1426.846   3.3  52.4 **                                       |
#       160          1246.644   2.9  55.3 **                                          |
#       170          1589.258   3.7  59.0 **                                             |
#       180          1317.348   3.0  62.1 **                                               |
#       190          1028.201   2.4  64.4 *                                                  |
#       200          1433.651   3.3  67.8 **                                                    |
#       210          1384.602   3.2  71.0 **                                                      |
#       220          1654.411   3.8  74.8 ***                                                        |
#       230          1388.595   3.2  78.0 **                                                            |
#       240          1431.290   3.3  81.3 **                                                               |
#       250          1176.392   2.7  84.0 **                                                                 |
#       260          1356.527   3.1  87.2 **                                                                   |
#       270          1336.175   3.1  90.3 **                                                                      |
#       280          1337.868   3.1  93.4 **                                                                        |
#       290          1450.037   3.4  96.7 **                                                                           |
#       300          1410.766   3.3 100.0 **                                                                             |
#           inf         0       0   100.0                                                                                |
#
# Statistics of carts at     43200.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of requesters of carts                duration          43200            0        43200
#                                              mean                  0
#                                              std.deviation         0
#
#                                              minimum               0
#                                              median                0
#                                              90% percentile        0
#                                              95% percentile        0
#                                              maximum               0
#
# Length of stay in requesters of carts        entries             780          780            0
#                                              mean                  0            0
#                                              std.deviation         0            0
#
#                                              minimum               0            0
#                                              median                0            0
#                                              90% percentile        0            0
#                                              95% percentile        0            0
#                                              maximum               0            0
#
# Length of claimers of carts                  duration          43200        21336.532    21863.468
#                                              mean                  1.033        2.091
#                                              std.deviation         1.517        1.565
#
#                                              minimum               0            1
#                                              median                0            2
#                                              90% percentile        3            4
#                                              95% percentile        4            5
#                                              maximum              11           11
#
# Length of stay in claimers of carts          entries             779          779            0
#                                              mean                 57.269       57.269
#                                              std.deviation        57.988       57.988
#
#                                              minimum               0.079        0.079
#                                              median               38.575       38.575
#                                              90% percentile      133.144      133.144
#                                              95% percentile      184.977      184.977
#                                              maximum             422.084      422.084
#
# Capacity of carts                            duration          43200        43200            0
#                                              mean                 45           45
#                                              std.deviation         0            0
#
#                                              minimum              45           45
#                                              median               45           45
#                                              90% percentile       45           45
#                                              95% percentile       45           45
#                                              maximum              45           45
#
# Available quantity of carts                  duration          43200        43200            0
#                                              mean                 43.967       43.967
#                                              std.deviation         1.517        1.517
#
#                                              minimum              34           34
#                                              median               45           45
#                                              90% percentile       45           45
#                                              95% percentile       45           45
#                                              maximum              45           45
#
# Claimed quantity of carts                    duration          43200        21336.532    21863.468
#                                              mean                  1.033        2.091
#                                              std.deviation         1.517        1.565
#
#                                              minimum               0            1
#                                              median                0            2
#                                              90% percentile        3            4
#                                              95% percentile        4            5
#                                              maximum              11           11
#
# Occupancy of carts                           duration          43200        21336.532    21863.468
#                                              mean                  0.023        0.046
#                                              std.deviation         0.034        0.035
#
#                                              minimum               0            0.022
#                                              median                0            0.044
#                                              90% percentile        0.067        0.089
#                                              95% percentile        0.089        0.111
#                                              maximum               0.244        0.244
#
# Resource 0x1b740fcd450
#   name=carts
#   capacity=45
#   no requesting components
#   claimed_quantity=1
#   claimed by:
#     customer.995         quantity=1
# Statistics of bread_clerks at     43200.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of requesters of bread_clerks         duration          43200        38091.590     5108.410
#                                              mean                 54.502       61.811
#                                              std.deviation        38.363       34.890
#
#                                              minimum               0            1
#                                              median               51           55
#                                              90% percentile      118          118
#                                              95% percentile      121          121
#                                              maximum             127          127
#
# Length of stay in requesters of bread_clerks entries             904          904            0
#                                              mean               2294.833     2294.833
#                                              std.deviation      1507.329     1507.329
#
#                                              minimum               0            0
#                                              median             2045.027     2045.027
#                                              90% percentile     4709.901     4709.901
#                                              95% percentile     5431.094     5431.094
#                                              maximum            5768.818     5768.818
#
# Length of claimers of bread_clerks           duration          43200        42146.917     1053.083
#                                              mean                  3.729        3.822
#                                              std.deviation         0.855        0.626
#
#                                              minimum               0            1
#                                              median                4            4
#                                              90% percentile        4            4
#                                              95% percentile        4            4
#                                              maximum               4            4
#
# Length of stay in claimers of bread_clerks   entries             900          900            0
#                                              mean                178.352      178.352
#                                              std.deviation       126.192      126.192
#
#                                              minimum              32.512       32.512
#                                              median              135.650      135.650
#                                              90% percentile      351.315      351.315
#                                              95% percentile      438.646      438.646
#                                              maximum             860.853      860.853
#
# Capacity of bread_clerks                     duration          43200        43200            0
#                                              mean                  4            4
#                                              std.deviation         0            0
#
#                                              minimum               4            4
#                                              median                4            4
#                                              90% percentile        4            4
#                                              95% percentile        4            4
#                                              maximum               4            4
#
# Available quantity of bread_clerks           duration          43200         4655.526    38544.474
#                                              mean                  0.271        2.517
#                                              std.deviation         0.855        1.061
#
#                                              minimum               0            1
#                                              median                0            3
#                                              90% percentile        1            4
#                                              95% percentile        3            4
#                                              maximum               4            4
#
# Claimed quantity of bread_clerks             duration          43200        42146.917     1053.083
#                                              mean                  3.729        3.822
#                                              std.deviation         0.855        0.626
#
#                                              minimum               0            1
#                                              median                4            4
#                                              90% percentile        4            4
#                                              95% percentile        4            4
#                                              maximum               4            4
#
# Occupancy of bread_clerks                    duration          43200        42146.917     1053.083
#                                              mean                  0.932        0.955
#                                              std.deviation         0.214        0.157
#
#                                              minimum               0            0.250
#                                              median                1            1
#                                              90% percentile        1            1
#                                              95% percentile        1            1
#                                              maximum               1            1
#
# Resource 0x1b740fb1b50
#   name=bread_clerks
#   capacity=4
#   requesting component(s):
#     customer.904         quantity=1
#     customer.905         quantity=1
#     customer.906         quantity=1
#     customer.907         quantity=1
#     customer.909         quantity=1
#     customer.908         quantity=1
#     customer.910         quantity=1
#     customer.912         quantity=1
#     customer.911         quantity=1
#     customer.913         quantity=1
#     customer.914         quantity=1
#     customer.915         quantity=1
#     customer.916         quantity=1
#     customer.917         quantity=1
#     customer.918         quantity=1
#     customer.920         quantity=1
#     customer.919         quantity=1
#     customer.921         quantity=1
#     customer.923         quantity=1
#     customer.922         quantity=1
#     customer.924         quantity=1
#     customer.925         quantity=1
#     customer.926         quantity=1
#     customer.927         quantity=1
#     customer.928         quantity=1
#     customer.929         quantity=1
#     customer.930         quantity=1
#     customer.931         quantity=1
#     customer.933         quantity=1
#     customer.932         quantity=1
#     customer.934         quantity=1
#     customer.935         quantity=1
#     customer.936         quantity=1
#     customer.937         quantity=1
#     customer.938         quantity=1
#     customer.939         quantity=1
#     customer.941         quantity=1
#     customer.940         quantity=1
#     customer.942         quantity=1
#     customer.943         quantity=1
#     customer.944         quantity=1
#     customer.945         quantity=1
#     customer.946         quantity=1
#     customer.947         quantity=1
#     customer.948         quantity=1
#     customer.949         quantity=1
#     customer.950         quantity=1
#     customer.951         quantity=1
#     customer.952         quantity=1
#     customer.953         quantity=1
#     customer.954         quantity=1
#     customer.955         quantity=1
#     customer.956         quantity=1
#     customer.957         quantity=1
#     customer.958         quantity=1
#     customer.959         quantity=1
#     customer.960         quantity=1
#     customer.961         quantity=1
#     customer.962         quantity=1
#     customer.963         quantity=1
#     customer.964         quantity=1
#     customer.965         quantity=1
#     customer.966         quantity=1
#     customer.967         quantity=1
#     customer.969         quantity=1
#     customer.968         quantity=1
#     customer.970         quantity=1
#     customer.971         quantity=1
#     customer.973         quantity=1
#     customer.972         quantity=1
#     customer.974         quantity=1
#     customer.975         quantity=1
#     customer.976         quantity=1
#     customer.977         quantity=1
#     customer.978         quantity=1
#     customer.979         quantity=1
#     customer.980         quantity=1
#     customer.983         quantity=1
#     customer.981         quantity=1
#     customer.982         quantity=1
#     customer.985         quantity=1
#     customer.984         quantity=1
#     customer.986         quantity=1
#     customer.987         quantity=1
#     customer.988         quantity=1
#     customer.989         quantity=1
#     customer.990         quantity=1
#     customer.991         quantity=1
#     customer.992         quantity=1
#     customer.993         quantity=1
#     customer.994         quantity=1
#   claimed_quantity=4
#   claimed by:
#     customer.900         quantity=1
#     customer.898         quantity=1
#     customer.902         quantity=1
#     customer.903         quantity=1
# Statistics of bread_clerks at     43200.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of requesters of bread_clerks         duration          43200          271.278    42928.722
#                                              mean                  0.006        1
#                                              std.deviation         0.079        0
#
#                                              minimum               0            1
#                                              median                0            1
#                                              90% percentile        0            1
#                                              95% percentile        0            1
#                                              maximum               1            1
#
# Length of stay in requesters of bread_clerks entries             901          901            0
#                                              mean                  0.301        0.301
#                                              std.deviation         2.309        2.309
#
#                                              minimum               0            0
#                                              median                0            0
#                                              90% percentile        0            0
#                                              95% percentile        0            0
#                                              maximum              25.821       25.821
#
# Length of claimers of bread_clerks           duration          43200        30156.243    13043.757
#                                              mean                  1.058        1.515
#                                              std.deviation         0.885        0.655
#
#                                              minimum               0            1
#                                              median                1            1
#                                              90% percentile        2            2
#                                              95% percentile        3            3
#                                              maximum               3            3
#
# Length of stay in claimers of bread_clerks   entries             900          900            0
#                                              mean                 50.720       50.720
#                                              std.deviation        12.604       12.604
#
#                                              minimum              19.620       19.620
#                                              median               49.902       49.902
#                                              90% percentile       67.639       67.639
#                                              95% percentile       72.999       72.999
#                                              maximum             100.321      100.321
#
# Capacity of bread_clerks                     duration          43200        43200            0
#                                              mean                  3            3
#                                              std.deviation         0            0
#
#                                              minimum               3            3
#                                              median                3            3
#                                              90% percentile        3            3
#                                              95% percentile        3            3
#                                              maximum               3            3
#
# Available quantity of bread_clerks           duration          43200        40496.793     2703.207
#                                              mean                  1.942        2.072
#                                              std.deviation         0.885        0.753
#
#                                              minimum               0            1
#                                              median                2            2
#                                              90% percentile        3            3
#                                              95% percentile        3            3
#                                              maximum               3            3
#
# Claimed quantity of bread_clerks             duration          43200        30156.243    13043.757
#                                              mean                  1.058        1.515
#                                              std.deviation         0.885        0.655
#
#                                              minimum               0            1
#                                              median                1            1
#                                              90% percentile        2            2
#                                              95% percentile        3            3
#                                              maximum               3            3
#
# Occupancy of bread_clerks                    duration          43200        30156.243    13043.757
#                                              mean                  0.353        0.505
#                                              std.deviation         0.295        0.218
#
#                                              minimum               0            0.333
#                                              median                0.333        0.333
#                                              90% percentile        0.667        0.667
#                                              95% percentile        1            1
#                                              maximum               1            1
#
# Resource 0x1b738a44310
#   name=bread_clerks
#   capacity=3
#   no requesting components
#   claimed_quantity=1
#   claimed by:
#     customer.900         quantity=1
# Histogram of Customer basket and cart monitor
# entries            996
#
# value               entries     %
# Resource (baskets)      216  21.7 *****************
# Resource (carts)        780  78.3 **************************************************************

# %%
sum([30, 80, 110, 90, 80, 70, 80, 90, 100, 120, 90, 40] )
# Out:
# 980

# %%
help(sim.Exponential)
# Out:
# Help on class Exponential in module salabim.salabim:
#
# class Exponential(_Distribution)
#  |  Exponential(mean: float = None, time_unit: str = None, rate: float = None, randomstream: Any = None, env: 'Environment' = None)
#  |
#  |  exponential distribution
#  |
#  |  Parameters
#  |  ----------
#  |  mean : float
#  |      mean of the distribtion (beta)
#  |
#  |      if omitted, the rate is used
#  |
#  |      must be >0
#  |
#  |  time_unit : str
#  |      specifies the time unit
#  |
#  |      must be one of "years", "weeks", "days", "hours", "minutes", "seconds", "milliseconds", "microseconds"
#  |
#  |      default : no conversion
#  |
#  |
#  |  rate : float
#  |      rate of the distribution (lambda)
#  |
#  |      if omitted, the mean is used
#  |
#  |      must be >0
#  |
#  |  randomstream: randomstream
#  |      randomstream to be used
#  |
#  |      if omitted, random will be used
#  |
#  |      if used as random.Random(12299)
#  |      it assigns a new stream with the specified seed
#  |
#  |  env : Environment
#  |      environment where the distribution is defined
#  |
#  |      if omitted, default_env will be used
#  |
#  |  Note
#  |  ----
#  |  Either mean or rate has to be specified, not both
#  |
#  |  Method resolution order:
#  |      Exponential
#  |      _Distribution
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, mean: float = None, time_unit: str = None, rate: float = None, randomstream: Any = None, env: 'Environment' = None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  mean(self) -> float
#  |      Returns
#  |      -------
#  |      Mean of the distribution : float
#  |
#  |  print_info(self, as_str: bool = False, file: <class 'TextIO'> = None) -> str
#  |      prints information about the distribution
#  |
#  |      Parameters
#  |      ----------
#  |      as_str: bool
#  |          if False (default), print the info
#  |          if True, return a string containing the info
#  |
#  |      file: file
#  |          if None(default), all output is directed to stdout
#  |
#  |          otherwise, the output is directed to the file
#  |
#  |      Returns
#  |      -------
#  |      info (if as_str is True) : str
#  |
#  |  sample(self) -> float
#  |      Returns
#  |      -------
#  |      Sample of the distribution : float
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _Distribution:
#  |
#  |  __add__(self, other)
#  |
#  |  __call__(self, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __floordiv__(self, other)
#  |
#  |  __mul__(self, other)
#  |
#  |  __neg__(self)
#  |
#  |  __pos__(self)
#  |
#  |  __pow__(self, other)
#  |
#  |  __radd__(self, other)
#  |
#  |  __rfloordiv__(self, other)
#  |
#  |  __rmul__(self, other)
#  |
#  |  __rpow__(self, other)
#  |
#  |  __rsub__(self, other)
#  |
#  |  __rtruediv__(self, other)
#  |
#  |  __sub__(self, other)
#  |
#  |  __truediv__(self, other)
#  |
#  |  bounded_sample(self, lowerbound: float = None, upperbound: float = None, fail_value: float = None, number_of_retries: int = None, include_lowerbound: bool = True, include_upperbound: bool = True) -> float
#  |      Parameters
#  |      ----------
#  |      lowerbound : float
#  |          sample values < lowerbound will be rejected (at most 100 retries)
#  |
#  |          if omitted, no lowerbound check
#  |
#  |      upperbound : float
#  |          sample values > upperbound will be rejected (at most 100 retries)
#  |
#  |          if omitted, no upperbound check
#  |
#  |      fail_value : float
#  |          value to be used if. after number_of_tries retries, sample is still not within bounds
#  |
#  |          default: lowerbound, if specified, otherwise upperbound
#  |
#  |      number_of_tries : int
#  |          number of tries before fail_value is returned
#  |
#  |          default: 100
#  |
#  |      include_lowerbound : bool
#  |          if True (default), the lowerbound may be included.
#  |          if False, the lowerbound will be excluded.
#  |
#  |      include_upperbound : bool
#  |          if True (default), the upperbound may be included.
#  |          if False, the upperbound will be excluded.
#  |
#  |      Returns
#  |      -------
#  |      Bounded sample of a distribution : depending on distribution type (usually float)
#  |
#  |      Note
#  |      ----
#  |      If, after number_of_tries retries, the sampled value is still not within the given bounds,
#  |      fail_value  will be returned
#  |
#  |      Samples that cannot be converted (only possible with Pdf and CumPdf) to float
#  |      are assumed to be within the bounds.
#  |
#  |  register_time_unit(self, time_unit, env)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _Distribution:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
help(sim.Triangular(4, 22,10))
# Out:
# Help on Triangular in module salabim.salabim object:
#
# class Triangular(_Distribution)
#  |  Triangular(low: float, high: float = None, mode: float = None, time_unit: str = None, randomstream: Any = None, env: 'Environment' = None)
#  |
#  |  triangular distribution
#  |
#  |  Parameters
#  |  ----------
#  |  low : float
#  |      lowerbound of the distribution
#  |
#  |  high : float
#  |      upperbound of the distribution
#  |
#  |      if omitted, low will be used, thus effectively a constant distribution
#  |
#  |      high must be >= low
#  |
#  |  mode : float
#  |      mode of the distribution
#  |
#  |      if omitted, the average of low and high will be used, thus a symmetric triangular distribution
#  |
#  |      mode must be between low and high
#  |
#  |  time_unit : str
#  |      specifies the time unit
#  |
#  |      must be one of "years", "weeks", "days", "hours", "minutes", "seconds", "milliseconds", "microseconds"
#  |
#  |      default : no conversion
#  |
#  |
#  |  randomstream: randomstream
#  |      randomstream to be used
#  |
#  |      if omitted, random will be used
#  |
#  |      if used as random.Random(12299)
#  |      it assigns a new stream with the specified seed
#  |
#  |  env : Environment
#  |      environment where the distribution is defined
#  |
#  |      if omitted, default_env will be used
#  |
#  |  Method resolution order:
#  |      Triangular
#  |      _Distribution
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, low: float, high: float = None, mode: float = None, time_unit: str = None, randomstream: Any = None, env: 'Environment' = None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  mean(self) -> float
#  |      Returns
#  |      -------
#  |      Mean of the distribution : float
#  |
#  |  print_info(self, as_str: bool = False, file: <class 'TextIO'> = None) -> str
#  |      prints information about the distribution
#  |
#  |      Parameters
#  |      ----------
#  |      as_str: bool
#  |          if False (default), print the info
#  |          if True, return a string containing the info
#  |
#  |      file: file
#  |          if None(default), all output is directed to stdout
#  |
#  |          otherwise, the output is directed to the file
#  |
#  |      Returns
#  |      -------
#  |      info (if as_str is True) : str
#  |
#  |  sample(self) -> float
#  |      Returns
#  |      -------
#  |      Sample of the distribtion : float
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _Distribution:
#  |
#  |  __add__(self, other)
#  |
#  |  __call__(self, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __floordiv__(self, other)
#  |
#  |  __mul__(self, other)
#  |
#  |  __neg__(self)
#  |
#  |  __pos__(self)
#  |
#  |  __pow__(self, other)
#  |
#  |  __radd__(self, other)
#  |
#  |  __rfloordiv__(self, other)
#  |
#  |  __rmul__(self, other)
#  |
#  |  __rpow__(self, other)
#  |
#  |  __rsub__(self, other)
#  |
#  |  __rtruediv__(self, other)
#  |
#  |  __sub__(self, other)
#  |
#  |  __truediv__(self, other)
#  |
#  |  bounded_sample(self, lowerbound: float = None, upperbound: float = None, fail_value: float = None, number_of_retries: int = None, include_lowerbound: bool = True, include_upperbound: bool = True) -> float
#  |      Parameters
#  |      ----------
#  |      lowerbound : float
#  |          sample values < lowerbound will be rejected (at most 100 retries)
#  |
#  |          if omitted, no lowerbound check
#  |
#  |      upperbound : float
#  |          sample values > upperbound will be rejected (at most 100 retries)
#  |
#  |          if omitted, no upperbound check
#  |
#  |      fail_value : float
#  |          value to be used if. after number_of_tries retries, sample is still not within bounds
#  |
#  |          default: lowerbound, if specified, otherwise upperbound
#  |
#  |      number_of_tries : int
#  |          number of tries before fail_value is returned
#  |
#  |          default: 100
#  |
#  |      include_lowerbound : bool
#  |          if True (default), the lowerbound may be included.
#  |          if False, the lowerbound will be excluded.
#  |
#  |      include_upperbound : bool
#  |          if True (default), the upperbound may be included.
#  |          if False, the upperbound will be excluded.
#  |
#  |      Returns
#  |      -------
#  |      Bounded sample of a distribution : depending on distribution type (usually float)
#  |
#  |      Note
#  |      ----
#  |      If, after number_of_tries retries, the sampled value is still not within the given bounds,
#  |      fail_value  will be returned
#  |
#  |      Samples that cannot be converted (only possible with Pdf and CumPdf) to float
#  |      are assumed to be within the bounds.
#  |
#  |  register_time_unit(self, time_unit, env)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _Distribution:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
import salabim as sim
help(sim.Pdf)
# Out:
# Help on class Pdf in module salabim.salabim:
#
# class Pdf(_Distribution)
#  |  Pdf(spec: Union[Iterable, Dict], probabilities=None, time_unit: str = None, randomstream: Any = None, env: 'Environment' = None)
#  |
#  |  Probability distribution function
#  |
#  |  Parameters
#  |  ----------
#  |  spec : list, tuple or dict
#  |      either
#  |
#  |      -   if no probabilities specified:
#  |
#  |          list/tuple with x-values and corresponding probability
#  |          dict where the keys are re x-values and the values are probabilities
#  |          (x0, p0, x1, p1, ...xn,pn)
#  |
#  |      -   if probabilities is specified:
#  |
#  |          list with x-values
#  |
#  |  probabilities : iterable or float
#  |      if omitted, spec contains the probabilities
#  |
#  |      the iterable (p0, p1, ...pn) contains the probabilities of the corresponding
#  |      x-values from spec.
#  |
#  |      alternatively, if a float is given (e.g. 1), all x-values
#  |      have equal probability. The value is not important.
#  |
#  |  time_unit : str
#  |      specifies the time unit
#  |
#  |      must be one of "years", "weeks", "days", "hours", "minutes", "seconds", "milliseconds", "microseconds"
#  |
#  |      default : no conversion
#  |
#  |
#  |  randomstream : randomstream
#  |      if omitted, random will be used
#  |
#  |      if used as random.Random(12299)
#  |      it assigns a new stream with the specified seed
#  |
#  |  env : Environment
#  |      environment where the distribution is defined
#  |
#  |      if omitted, default_env will be used
#  |
#  |  Note
#  |  ----
#  |  p0+p1=...+pn>0
#  |
#  |  all densities are auto scaled according to the sum of p0 to pn,
#  |  so no need to have p0 to pn add up to 1 or 100.
#  |
#  |  The x-values can be any type.
#  |
#  |  If it is a salabim distribution, not the distribution,
#  |  but a sample will be returned when calling sample.
#  |
#  |  Method resolution order:
#  |      Pdf
#  |      _Distribution
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, spec: Union[Iterable, Dict], probabilities=None, time_unit: str = None, randomstream: Any = None, env: 'Environment' = None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  mean(self) -> float
#  |      Returns
#  |      -------
#  |      mean of the distribution : float
#  |          if the mean can't be calculated (if not all x-values are scalars or distributions),
#  |          nan will be returned.
#  |
#  |  print_info(self, as_str: bool = False, file: <class 'TextIO'> = None) -> str
#  |      prints information about the distribution
#  |
#  |      Parameters
#  |      ----------
#  |      as_str: bool
#  |          if False (default), print the info
#  |          if True, return a string containing the info
#  |
#  |      file: file
#  |          if None(default), all output is directed to stdout
#  |
#  |          otherwise, the output is directed to the file
#  |
#  |      Returns
#  |      -------
#  |      info (if as_str is True) : str
#  |
#  |  sample(self, n: int = None) -> Any
#  |      Parameters
#  |      ----------
#  |      n : number of samples : int
#  |          if not specified, specifies just return one sample, as usual
#  |
#  |          if specified, return a list of n sampled values from the distribution without replacement.
#  |          This requires that all probabilities are equal.
#  |
#  |          If n > number of values in the Pdf distribution, n is assumed to be the number of values
#  |          in the distribution.
#  |
#  |          If a sampled value is a distribution, a sample from that distribution will be returned.
#  |
#  |      Returns
#  |      -------
#  |      Sample of the distribution : any (usually float) or list
#  |          In case n is specified, returns a list of n values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _Distribution:
#  |
#  |  __add__(self, other)
#  |
#  |  __call__(self, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __floordiv__(self, other)
#  |
#  |  __mul__(self, other)
#  |
#  |  __neg__(self)
#  |
#  |  __pos__(self)
#  |
#  |  __pow__(self, other)
#  |
#  |  __radd__(self, other)
#  |
#  |  __rfloordiv__(self, other)
#  |
#  |  __rmul__(self, other)
#  |
#  |  __rpow__(self, other)
#  |
#  |  __rsub__(self, other)
#  |
#  |  __rtruediv__(self, other)
#  |
#  |  __sub__(self, other)
#  |
#  |  __truediv__(self, other)
#  |
#  |  bounded_sample(self, lowerbound: float = None, upperbound: float = None, fail_value: float = None, number_of_retries: int = None, include_lowerbound: bool = True, include_upperbound: bool = True) -> float
#  |      Parameters
#  |      ----------
#  |      lowerbound : float
#  |          sample values < lowerbound will be rejected (at most 100 retries)
#  |
#  |          if omitted, no lowerbound check
#  |
#  |      upperbound : float
#  |          sample values > upperbound will be rejected (at most 100 retries)
#  |
#  |          if omitted, no upperbound check
#  |
#  |      fail_value : float
#  |          value to be used if. after number_of_tries retries, sample is still not within bounds
#  |
#  |          default: lowerbound, if specified, otherwise upperbound
#  |
#  |      number_of_tries : int
#  |          number of tries before fail_value is returned
#  |
#  |          default: 100
#  |
#  |      include_lowerbound : bool
#  |          if True (default), the lowerbound may be included.
#  |          if False, the lowerbound will be excluded.
#  |
#  |      include_upperbound : bool
#  |          if True (default), the upperbound may be included.
#  |          if False, the upperbound will be excluded.
#  |
#  |      Returns
#  |      -------
#  |      Bounded sample of a distribution : depending on distribution type (usually float)
#  |
#  |      Note
#  |      ----
#  |      If, after number_of_tries retries, the sampled value is still not within the given bounds,
#  |      fail_value  will be returned
#  |
#  |      Samples that cannot be converted (only possible with Pdf and CumPdf) to float
#  |      are assumed to be within the bounds.
#  |
#  |  register_time_unit(self, time_unit, env)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _Distribution:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
